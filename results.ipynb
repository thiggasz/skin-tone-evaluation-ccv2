# %%
import matplotlib.pyplot as plt
from analysis.results_analysis import analyse_results, analyse_ml_results, calculate_confidence_intervals
from src.machine_learning import random_forest, mlp_classifier
import pandas as pd

# %% [markdown]
# # Colorimétricos

# %% [markdown]
# ## ITA°

# %%
ita_fitz = ' '
analyse_results(ita_fitz, 'ita', 'fitzpatrick_type')
# Out:
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#            1       0.20      0.28      0.24       819
#            2       0.29      0.31      0.30      2178
#            3       0.28      0.28      0.28      2643
#            4       0.29      0.18      0.22      3010
#            5       0.32      0.23      0.27      2412
#            6       0.16      0.40      0.23       874
#
#     accuracy                           0.26     11936
#    macro avg       0.26      0.28      0.26     11936
# weighted avg       0.28      0.26      0.26     11936
#
#
# --- Ordinal Metrics ---
# Global Accuracy:            0.2593
# Macro F1-Score:             0.2553
# Off-by-One Accuracy:        0.6763
# Macro Mean Absolute Error:  1.2705
# Macro Mean Quadratic Error: 2.9945
# Quadratic Weighted Kappa:   0.4228

# %%
ita_monk = ' '

analyse_results(ita_monk, 'ita', 'monk_scale')
# Out:
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#            1       0.03      0.00      0.01       300
#            2       0.34      0.01      0.02      1717
#            3       0.21      0.02      0.04      1553
#            4       0.15      0.03      0.05      1910
#            5       0.13      0.10      0.11      2765
#            6       0.17      0.43      0.24      1426
#            7       0.10      0.24      0.14       993
#            8       0.10      0.27      0.14       795
#            9       0.08      0.17      0.11       390
#           10       0.11      0.15      0.13        87
#
#     accuracy                           0.13     11936
#    macro avg       0.14      0.14      0.10     11936
# weighted avg       0.17      0.13      0.10     11936
#
#
# --- Ordinal Metrics ---
# Global Accuracy:            0.1289
# Macro F1-Score:             0.0998
# Off-by-One Accuracy:        0.3637
# Macro Mean Absolute Error:  2.1959
# ...

# %% [markdown]
# ## Cluster

# %%
cluster_fitz = ' '

analyse_results(cluster_fitz, 'cluster', 'fitzpatrick_type')
# Out:
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#            1       0.15      0.04      0.06       819
#            2       0.34      0.08      0.13      2178
#            3       0.30      0.26      0.28      2643
#            4       0.27      0.28      0.27      3010
#            5       0.22      0.22      0.22      2412
#            6       0.15      0.58      0.24       874
#
#     accuracy                           0.23     11936
#    macro avg       0.24      0.24      0.20     11936
# weighted avg       0.26      0.23      0.22     11936
#
#
# --- Ordinal Metrics ---
# Global Accuracy:            0.2322
# Macro F1-Score:             0.2002
# Off-by-One Accuracy:        0.6328
# Macro Mean Absolute Error:  1.4356
# Macro Mean Quadratic Error: 3.5658
# Quadratic Weighted Kappa:   0.3233

# %%
cluster_monk = ' '

analyse_results(cluster_monk, 'clusterização', 'monk_scale')
# Out:
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#            1       0.09      0.00      0.01       300
#            2       0.28      0.04      0.06      1717
#            3       0.00      0.00      0.00      1553
#            4       0.00      0.00      0.00      1910
#            5       0.13      0.07      0.09      2765
#            6       0.17      0.41      0.24      1426
#            7       0.10      0.32      0.15       993
#            8       0.10      0.37      0.16       795
#            9       0.10      0.19      0.13       390
#           10       0.04      0.01      0.02        87
#
#     accuracy                           0.13     11936
#    macro avg       0.10      0.14      0.09     11936
# weighted avg       0.11      0.13      0.09     11936
#
#
# --- Ordinal Metrics ---
# Global Accuracy:            0.1285
# Macro F1-Score:             0.0867
# Off-by-One Accuracy:        0.3396
# Macro Mean Absolute Error:  2.2318
# ...

# %% [markdown]
# # Machine learning

# %% [markdown]
# ## Random Forest

# %%
random_forest('fitzpatrick_type')
# Out:
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#            1       0.27      0.02      0.04       819
#            2       0.37      0.39      0.38      2178
#            3       0.30      0.43      0.35      2643
#            4       0.38      0.37      0.37      3010
#            5       0.44      0.44      0.44      2412
#            6       0.41      0.20      0.27       874
#
#     accuracy                           0.36     11936
#    macro avg       0.36      0.31      0.31     11936
# weighted avg       0.37      0.36      0.35     11936
#
#
# --- Ordinal Metrics ---
# Global Accuracy:            0.3646
# Macro F1-Score:             0.3107
# Off-by-One Accuracy:        0.7926
# Macro Mean Absolute Error:  1.0853
# Macro Mean Quadratic Error: 2.1659
# Quadratic Weighted Kappa:   0.4824

# %%
path_rf_fitz = ' '
df_rf_fitz = pd.read_csv(path_rf_fitz)

analyse_ml_results(df_rf_fitz, 'Random Forest', 'fitzpatrick_type')
# Out:
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#            1       0.27      0.02      0.04       819
#            2       0.37      0.39      0.38      2178
#            3       0.30      0.43      0.35      2643
#            4       0.38      0.37      0.37      3010
#            5       0.44      0.44      0.44      2412
#            6       0.41      0.20      0.27       874
#
#     accuracy                           0.36     11936
#    macro avg       0.36      0.31      0.31     11936
# weighted avg       0.37      0.36      0.35     11936
#
#
# --- Ordinal Metrics ---
# Global Accuracy:            0.3646
# Macro F1-Score:             0.3107
# Off-by-One Accuracy:        0.7926
# Macro Mean Absolute Error:  1.0853
# Macro Mean Quadratic Error: 2.1659
# Quadratic Weighted Kappa:   0.4824

# %%
rf_f_path = ' '
rf_f_stats = calculate_confidence_intervals(rf_f_path, is_cnn=False)
rf_f_stats.to_csv('rf_fitz_stats.csv', index=False)
# Out:
# Calculando IC de 95% (T-Student) para 5 Folds...

# %%
random_forest('monk_scale')
# Out:
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#            1       0.05      0.01      0.01       300
#            2       0.34      0.36      0.35      1717
#            3       0.23      0.24      0.23      1553
#            4       0.21      0.30      0.25      1910
#            5       0.44      0.64      0.52      2765
#            6       0.34      0.23      0.27      1426
#            7       0.22      0.04      0.06       993
#            8       0.27      0.13      0.17       795
#            9       0.23      0.11      0.15       390
#           10       0.00      0.00      0.00        87
#
#     accuracy                           0.32     11936
#    macro avg       0.23      0.21      0.20     11936
# weighted avg       0.30      0.32      0.30     11936
#
#
# --- Ordinal Metrics ---
# Global Accuracy:            0.3220
# Macro F1-Score:             0.2026
# Off-by-One Accuracy:        0.6179
# Macro Mean Absolute Error:  2.1111
# ...

# %%
path_rf_monk = ' '
df_rf_monk = pd.read_csv(path_rf_monk)

analyse_ml_results(df_rf_monk, 'Random Forest', 'monk_scale')
# Out:
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#            1       0.05      0.01      0.01       300
#            2       0.34      0.36      0.35      1717
#            3       0.23      0.24      0.23      1553
#            4       0.21      0.30      0.25      1910
#            5       0.44      0.64      0.52      2765
#            6       0.34      0.23      0.27      1426
#            7       0.22      0.04      0.06       993
#            8       0.27      0.13      0.17       795
#            9       0.23      0.11      0.15       390
#           10       0.00      0.00      0.00        87
#
#     accuracy                           0.32     11936
#    macro avg       0.23      0.21      0.20     11936
# weighted avg       0.30      0.32      0.30     11936
#
#
# --- Ordinal Metrics ---
# Global Accuracy:            0.3220
# Macro F1-Score:             0.2026
# Off-by-One Accuracy:        0.6179
# Macro Mean Absolute Error:  2.1111
# ...

# %%
rf_m_path = ' '

rf_m_stats = calculate_confidence_intervals(rf_m_path, is_cnn=False)
rf_m_stats.to_csv('rf_monk_stats.csv', index=False)
# Out:
# Calculando IC de 95% (T-Student) para 5 Folds...

# %% [markdown]
# ## MLP

# %%
mlp_fitz = mlp_classifier('fitzpatrick_type')
# Out:
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#            1       0.27      0.14      0.18       819
#            2       0.32      0.30      0.31      2178
#            3       0.27      0.33      0.30      2643
#            4       0.32      0.37      0.35      3010
#            5       0.38      0.35      0.36      2412
#            6       0.34      0.22      0.27       874
#
#     accuracy                           0.32     11936
#    macro avg       0.32      0.29      0.29     11936
# weighted avg       0.32      0.32      0.32     11936
#
#
# --- Ordinal Metrics ---
# Global Accuracy:            0.3184
# Macro F1-Score:             0.2945
# Off-by-One Accuracy:        0.7419
# Macro Mean Absolute Error:  1.2084
# Macro Mean Quadratic Error: 2.6322
# Quadratic Weighted Kappa:   0.3883

# %%
path_mlp_fitz = ' '
df_mlp_fitz = pd.read_csv(path_mlp_fitz)

analyse_ml_results(df_mlp_fitz, 'MLP', 'fitzpatrick_type')
# Out:
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#            1       0.27      0.14      0.18       819
#            2       0.32      0.30      0.31      2178
#            3       0.27      0.33      0.30      2643
#            4       0.32      0.37      0.35      3010
#            5       0.38      0.35      0.36      2412
#            6       0.34      0.22      0.27       874
#
#     accuracy                           0.32     11936
#    macro avg       0.32      0.29      0.29     11936
# weighted avg       0.32      0.32      0.32     11936
#
#
# --- Ordinal Metrics ---
# Global Accuracy:            0.3184
# Macro F1-Score:             0.2945
# Off-by-One Accuracy:        0.7419
# Macro Mean Absolute Error:  1.2084
# Macro Mean Quadratic Error: 2.6322
# Quadratic Weighted Kappa:   0.3883

# %%
mlp_f_path = ' '

mlp_f_stats = calculate_confidence_intervals(mlp_f_path, is_cnn=False)
mlp_f_stats.to_csv('mlp_fitz_stats.csv', index=False)
# Out:
# Calculando IC de 95% (T-Student) para 5 Folds...

# %%
mlp_monk = mlp_classifier('monk_scale')
# Out:
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#            1       0.14      0.08      0.10       300
#            2       0.28      0.22      0.25      1717
#            3       0.20      0.25      0.22      1553
#            4       0.19      0.21      0.20      1910
#            5       0.42      0.51      0.46      2765
#            6       0.20      0.23      0.21      1426
#            7       0.18      0.12      0.15       993
#            8       0.24      0.15      0.19       795
#            9       0.17      0.11      0.13       390
#           10       0.06      0.02      0.03        87
#
#     accuracy                           0.27     11936
#    macro avg       0.21      0.19      0.19     11936
# weighted avg       0.26      0.27      0.26     11936
#
#
# --- Ordinal Metrics ---
# Global Accuracy:            0.2684
# Macro F1-Score:             0.1943
# Off-by-One Accuracy:        0.5814
# Macro Mean Absolute Error:  2.1984
# ...

# %%
path_mlp_monk = ' '
df_mlp_monk = pd.read_csv(path_mlp_monk)

analyse_ml_results(df_mlp_monk, 'MLP', 'monk_scale')
# Out:
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#            1       0.14      0.08      0.10       300
#            2       0.28      0.22      0.25      1717
#            3       0.20      0.25      0.22      1553
#            4       0.19      0.21      0.20      1910
#            5       0.42      0.51      0.46      2765
#            6       0.20      0.23      0.21      1426
#            7       0.18      0.12      0.15       993
#            8       0.24      0.15      0.19       795
#            9       0.17      0.11      0.13       390
#           10       0.06      0.02      0.03        87
#
#     accuracy                           0.27     11936
#    macro avg       0.21      0.19      0.19     11936
# weighted avg       0.26      0.27      0.26     11936
#
#
# --- Ordinal Metrics ---
# Global Accuracy:            0.2684
# Macro F1-Score:             0.1943
# Off-by-One Accuracy:        0.5814
# Macro Mean Absolute Error:  2.1984
# ...

# %%
mlp_m_path = ' '

mlp_m_stats = calculate_confidence_intervals(mlp_m_path, is_cnn=False)
mlp_m_stats.to_csv('mlp_monk_stats.csv', index=False)
# Out:
# Calculando IC de 95% (T-Student) para 5 Folds...

# %% [markdown]
# # CNN

# %% [markdown]
# ### DenseNet121

# %%
path_dense_fitz = ' '
df_dense_fitz = pd.read_csv(path_dense_fitz)

analyse_ml_results(df_dense_fitz, 'DenseNet121', 'fitzpatrick_type')
# Out:
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#            1       0.23      0.25      0.24       690
#            2       0.42      0.53      0.46      1852
#            3       0.38      0.37      0.37      2227
#            4       0.50      0.37      0.42      2734
#            5       0.54      0.50      0.52      2362
#            6       0.44      0.68      0.53       750
#
#     accuracy                           0.44     10615
#    macro avg       0.42      0.45      0.42     10615
# weighted avg       0.45      0.44      0.44     10615
#
#
# --- Ordinal Metrics ---
# Global Accuracy:            0.4384
# Macro F1-Score:             0.4246
# Off-by-One Accuracy:        0.8460
# Macro Mean Absolute Error:  0.8126
# Macro Mean Quadratic Error: 1.6517
# Quadratic Weighted Kappa:   0.6359

# %%
dense_f_path = ' '

dense_f_stats = calculate_confidence_intervals(dense_f_path, is_cnn=True)
dense_f_stats.to_csv('dense_fitz_stats.csv', index=False)
# Out:
# Calculando IC de 95% (T-Student) para 5 Folds...

# %%
path_dense_monk = ' '
df_dense_monk = pd.read_csv(path_dense_monk)

analyse_ml_results(df_dense_monk, 'DenseNet121', 'monk_scale')
# Out:
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#            1       0.13      0.30      0.19       260
#            2       0.37      0.34      0.36      1460
#            3       0.25      0.29      0.27      1308
#            4       0.25      0.15      0.18      1644
#            5       0.73      0.53      0.61      2705
#            6       0.33      0.22      0.26      1276
#            7       0.18      0.21      0.19       874
#            8       0.36      0.44      0.40       688
#            9       0.20      0.33      0.25       310
#           10       0.01      0.09      0.02        90
#
#     accuracy                           0.33     10615
#    macro avg       0.28      0.29      0.27     10615
# weighted avg       0.39      0.33      0.35     10615
#
#
# --- Ordinal Metrics ---
# Global Accuracy:            0.3306
# Macro F1-Score:             0.2719
# Off-by-One Accuracy:        0.6378
# Macro Mean Absolute Error:  1.6563
# ...

# %%
dense_m_path = ' '

dense_m_stats = calculate_confidence_intervals(dense_m_path, is_cnn=True)
dense_m_stats.to_csv('dense_monk_stats.csv', index=False)
# Out:
# Calculando IC de 95% (T-Student) para 5 Folds...

# %% [markdown]
# ### ConvNeXt-Tiny

# %%
path_convnext_fitz = ' '
df_convnext_fitz = pd.read_csv(path_convnext_fitz)

analyse_ml_results(df_convnext_fitz, 'ConvNeXt-Tiny', 'fitzpatrick_type')
# Out:
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#            1       0.29      0.25      0.27       690
#            2       0.43      0.53      0.47      1852
#            3       0.38      0.39      0.39      2227
#            4       0.50      0.38      0.43      2734
#            5       0.53      0.54      0.54      2362
#            6       0.51      0.65      0.57       750
#
#     accuracy                           0.46     10615
#    macro avg       0.44      0.46      0.45     10615
# weighted avg       0.46      0.46      0.45     10615
#
#
# --- Ordinal Metrics ---
# Global Accuracy:            0.4564
# Macro F1-Score:             0.4460
# Off-by-One Accuracy:        0.8713
# Macro Mean Absolute Error:  0.7387
# Macro Mean Quadratic Error: 1.3332
# Quadratic Weighted Kappa:   0.6838

# %%
conv_f_path = ' '

conv_f_stats = calculate_confidence_intervals(conv_f_path, is_cnn=True)
conv_f_stats.to_csv('conv_fitz_stats.csv', index=False)
# Out:
# Calculando IC de 95% (T-Student) para 5 Folds...

# %%
path_convnext_monk = ' '
df_convnext_monk = pd.read_csv(path_convnext_monk)

analyse_ml_results(df_convnext_monk, 'ConvNeXt-Tiny', 'monk_scale')
# Out:
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#            1       0.11      0.21      0.14       260
#            2       0.38      0.40      0.39      1460
#            3       0.27      0.27      0.27      1308
#            4       0.28      0.18      0.22      1644
#            5       0.75      0.58      0.65      2705
#            6       0.32      0.33      0.33      1276
#            7       0.19      0.20      0.20       874
#            8       0.38      0.37      0.38       688
#            9       0.27      0.46      0.34       310
#           10       0.02      0.14      0.04        90
#
#     accuracy                           0.36     10615
#    macro avg       0.30      0.32      0.30     10615
# weighted avg       0.41      0.36      0.38     10615
#
#
# --- Ordinal Metrics ---
# Global Accuracy:            0.3638
# Macro F1-Score:             0.2951
# Off-by-One Accuracy:        0.6834
# Macro Mean Absolute Error:  1.4245
# ...

# %%
conv_m_path = ' '

conv_m_stats = calculate_confidence_intervals(conv_m_path, is_cnn=True)
conv_m_stats.to_csv('conv_monk_stats.csv', index=False)
# Out:
# Calculando IC de 95% (T-Student) para 5 Folds...

# %% [markdown]
# # VLMs

# %% [markdown]
# ## Gemini

# %% [markdown]
# ### Fitzpatrick

# %%
gemini_fitz_skin = ' '

analyse_results(gemini_fitz_skin, 'gemini', 'fitzpatrick')
# Out:
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#            1       0.27      0.01      0.03       820
#            2       0.37      0.84      0.52      2178
#            3       0.30      0.36      0.33      2654
#            4       0.37      0.38      0.38      3175
#            5       0.48      0.12      0.19      2742
#            6       0.66      0.37      0.47       880
#
#     accuracy                           0.37     12449
#    macro avg       0.41      0.35      0.32     12449
# weighted avg       0.40      0.37      0.33     12449
#
#
# --- Ordinal Metrics ---
# Global Accuracy:            0.3723
# Macro F1-Score:             0.3179
# Off-by-One Accuracy:        0.8538
# Macro Mean Absolute Error:  0.8690
# Macro Mean Quadratic Error: 1.4551
# Quadratic Weighted Kappa:   0.6138

# %%
gemini_fitz_full = ' '

analyse_results(gemini_fitz_full, 'gemini', 'fitzpatrick')
# Out:
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#            1       0.62      0.01      0.01       820
#            2       0.55      0.50      0.52      2182
#            3       0.46      0.56      0.50      2660
#            4       0.43      0.77      0.56      3175
#            5       0.66      0.17      0.27      2748
#            6       0.76      0.77      0.76       880
#
#     accuracy                           0.49     12465
#    macro avg       0.58      0.46      0.44     12465
# weighted avg       0.54      0.49      0.45     12465
#
#
# --- Ordinal Metrics ---
# Global Accuracy:            0.4945
# Macro F1-Score:             0.4370
# Off-by-One Accuracy:        0.9690
# Macro Mean Absolute Error:  0.5974
# Macro Mean Quadratic Error: 0.7299
# Quadratic Weighted Kappa:   0.7919

# %% [markdown]
# ### Monk

# %%
gemini_monk_skin = ' '

analyse_results(gemini_monk_skin, 'gemini', 'monk')
# Out:
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#            1       0.11      0.35      0.17       300
#            2       0.28      0.63      0.39      1719
#            3       0.11      0.23      0.15      1551
#            4       0.14      0.03      0.05      1938
#            5       0.48      0.37      0.42      3175
#            6       0.09      0.03      0.05      1486
#            7       0.07      0.03      0.04      1000
#            8       0.21      0.06      0.09       800
#            9       0.29      0.18      0.22       390
#           10       0.23      0.56      0.32        90
#
#     accuracy                           0.24     12449
#    macro avg       0.20      0.25      0.19     12449
# weighted avg       0.24      0.24      0.21     12449
#
#
# --- Ordinal Metrics ---
# Global Accuracy:            0.2412
# Macro F1-Score:             0.1891
# Off-by-One Accuracy:        0.5457
# Macro Mean Absolute Error:  1.7091
# ...

# %%
gemini_monk_full = ' '

analyse_results(gemini_monk_full, 'gemini', 'monk')
# Out:
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#            1       0.22      0.16      0.19       300
#            2       0.48      0.57      0.52      1720
#            3       0.26      0.46      0.33      1558
#            4       0.26      0.29      0.27      1940
#            5       0.50      0.58      0.54      3175
#            6       0.11      0.02      0.03      1486
#            7       0.20      0.07      0.11      1006
#            8       0.25      0.08      0.13       800
#            9       0.24      0.26      0.25       390
#           10       0.19      0.92      0.31        90
#
#     accuracy                           0.36     12465
#    macro avg       0.27      0.34      0.27     12465
# weighted avg       0.33      0.36      0.33     12465
#
#
# --- Ordinal Metrics ---
# Global Accuracy:            0.3603
# Macro F1-Score:             0.2682
# Off-by-One Accuracy:        0.7544
# Macro Mean Absolute Error:  0.9835
# ...

# %% [markdown]
# ## Qwen

# %% [markdown]
# ### Fitzpatrick

# %%
qwen_fitz_skin = ' '

analyse_results(qwen_fitz_skin, 'qwen', 'fitzpatrick')
# Out:
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00       820
#            2       0.30      0.64      0.40      2182
#            3       0.64      0.00      0.01      2660
#            4       0.32      0.69      0.43      3175
#            5       0.00      0.00      0.00      2748
#            6       0.08      0.07      0.08       880
#
#     accuracy                           0.29     12465
#    macro avg       0.22      0.23      0.15     12465
# weighted avg       0.27      0.29      0.19     12465
#
#
# --- Ordinal Metrics ---
# Global Accuracy:            0.2924
# Macro F1-Score:             0.1533
# Off-by-One Accuracy:        0.7148
# Macro Mean Absolute Error:  1.3793
# Macro Mean Quadratic Error: 3.3220
# Quadratic Weighted Kappa:   0.2599

# %%
qwen_fitz_full = ' '

analyse_results(qwen_fitz_full, 'qwen', 'fitzpatrick')
# Out:
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00       820
#            2       0.47      0.51      0.49      2182
#            3       0.42      0.14      0.21      2660
#            4       0.29      0.85      0.44      3175
#            5       0.00      0.00      0.00      2748
#            6       0.04      0.00      0.01       880
#
#     accuracy                           0.33     12465
#    macro avg       0.20      0.25      0.19     12465
# weighted avg       0.25      0.33      0.24     12465
#
#
# --- Ordinal Metrics ---
# Global Accuracy:            0.3338
# Macro F1-Score:             0.1895
# Off-by-One Accuracy:        0.8089
# Macro Mean Absolute Error:  1.1504
# Macro Mean Quadratic Error: 2.1222
# Quadratic Weighted Kappa:   0.4364

# %% [markdown]
# ### Monk

# %%
qwen_monk_skin = ' '

analyse_results(qwen_monk_skin, 'qwen', 'monk')
# Out:
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00       300
#            2       0.00      0.00      0.00      1720
#            3       0.00      0.00      0.00      1558
#            4       0.19      0.23      0.21      1940
#            5       0.12      0.09      0.10      3175
#            6       0.11      0.00      0.01      1486
#            7       0.10      0.66      0.17      1006
#            8       0.00      0.00      0.00       800
#            9       0.03      0.06      0.04       390
#           10       0.00      0.00      0.00        90
#
#     accuracy                           0.11     12465
#    macro avg       0.05      0.10      0.05     12465
# weighted avg       0.08      0.11      0.07     12465
#
#
# --- Ordinal Metrics ---
# Global Accuracy:            0.1146
# Macro F1-Score:             0.0524
# Off-by-One Accuracy:        0.3764
# Macro Mean Absolute Error:  2.3760
# ...

# %%
qwen_monk_full = ' '
analyse_results(qwen_monk_full, 'qwen', 'monk')
# Out:
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00       300
#            2       0.00      0.00      0.00      1720
#            3       0.00      0.00      0.00      1558
#            4       0.15      0.06      0.09      1940
#            5       0.07      0.04      0.05      3175
#            6       0.14      0.80      0.24      1486
#            7       0.12      0.19      0.15      1006
#            8       0.00      0.00      0.00       800
#            9       0.04      0.01      0.02       390
#           10       0.00      0.00      0.00        90
#
#     accuracy                           0.13     12465
#    macro avg       0.05      0.11      0.05     12465
# weighted avg       0.07      0.13      0.07     12465
#
#
# --- Ordinal Metrics ---
# Global Accuracy:            0.1296
# Macro F1-Score:             0.0541
# Off-by-One Accuracy:        0.4587
# Macro Mean Absolute Error:  2.2760
# ...
